# %% [markdown]
# ## Datos agrupados con pandas: group_by

# %%
import pandas as pd

# %%
path = "ficheros/Pedidos.html"
L = pd.read_html(path)
df = L[0]
df.head()
# Out:
#    Unnamed: 0  idpedido cliente  importe         pais  empleado  \
# 0           0     10248   WILMK    32.38    Finlandia  Buchanan
# 1           1     10320   WARTH    34.57    Finlandia  Buchanan
# 2           2     10333   WARTH     0.59    Finlandia  Buchanan
# 3           3     10359   SEVES   288.43  Reino Unido  Buchanan
# 4           4     10378   FOLKO     5.44       Suecia  Buchanan
#
#                cargo           empresa
# 0  Gerente de ventas  Federal Shipping
# 1  Gerente de ventas  Federal Shipping
# 2  Gerente de ventas  Federal Shipping
# 3  Gerente de ventas  Federal Shipping
# 4  Gerente de ventas  Federal Shipping
