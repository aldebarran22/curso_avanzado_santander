# %% [markdown]
# ## Dataframe pandas

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
m = np.arange(30).reshape(6,-1)
df = DataFrame(m, columns=list('abcde'))
df
# Out:
#     a   b   c   d   e
# 0   0   1   2   3   4
# 1   5   6   7   8   9
# 2  10  11  12  13  14
# 3  15  16  17  18  19
# 4  20  21  22  23  24
# 5  25  26  27  28  29

# %%
df.shape
# Out:
# (6, 5)

# %%
df['a']
# Out:
# 0     0
# 1     5
# 2    10
# 3    15
# 4    20
# 5    25
# Name: a, dtype: int32

# %%
df.loc[0]
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# Name: 0, dtype: int32

# %%
df['e'][5], df.loc[5]['e']
# Out:
# (29, 29)
