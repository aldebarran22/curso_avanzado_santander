# %% [markdown]
# ## Pruebas con pandas

# %% [markdown]
# ### Series

# %%
import pandas as pd
import numpy as np
from pandas import Series

# %%
s1 = Series([1,4,5,6,9])
s2 = Series(np.arange(10))

# %%
s1
# Out:
# 0    1
# 1    4
# 2    5
# 3    6
# 4    9
# dtype: int64

# %%
s3 = Series([1,2,3,4,5], index=list('abcbd'))
s3
# Out:
# a    1
# b    2
# c    3
# b    4
# d    5
# dtype: int64

# %%
s3['a'], s3[0], s3[-5]
# Out:
# (1, 1, 1)

# %%
s4 = s3[['a','b','d']]
s4
# Out:
# a    1
# b    2
# b    4
# d    5
# dtype: int64
